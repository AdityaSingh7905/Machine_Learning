# %% [markdown]
# <h1>Fetching Data using an API</h1>

# %%
import requests
import pandas as pd

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3YzM5YzRlZGQ5ZTcyOTYwZmE4OTM5YTZiNDZiMTA4MiIsIm5iZiI6MTcyMzg4OTk3MS4wODg3OTgsInN1YiI6IjY2YzA3NjRlMDJmMzIwOTU3YTFmNTU5ZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qNu0FDAn6hspH7ncORbOYufyInnEVFSVNm3NkvTCaH8"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/avedvodAZUcwqevBfm8p4G2NziQ.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 128.372, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.706, 'vote_count': 26631}, {'adult': False, 'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]

# %%
df
# Out:
#         id  popularity release_date  \
# 0      278     128.372   1994-09-23
# 1      238     260.690   1972-03-14
# 2      240      84.401   1974-12-20
# 3      424      96.342   1993-12-15
# 4      389      68.522   1957-04-10
# 5      129     100.376   2001-07-20
# 6    19404      33.059   1995-10-20
# 7      155     158.693   2008-07-16
# 8   496243      87.142   2019-05-30
# 9      497     101.556   1999-12-10
# 10  372058      77.841   2016-08-26
# 11     680     120.692   1994-09-10
# 12     122     106.504   2003-12-01
# 13      13      96.558   1994-06-23
# 14     429      74.993   1966-12-22
# 15     769     111.746   1990-09-12
# 16     346      42.852   1954-04-26
# 17  667257      23.485   2021-06-17
# 18   12477       0.040   1988-04-16
# 19     637      41.896   1997-12-20
#
#                                             title  vote_average  vote_count
# 0                        The Shawshank Redemption         8.706       26631
# ...

# %% [markdown]
# <h1>#Now, we have to perform loop in order to get all the movies from all the pages</h1>

# %%
dp = pd.DataFrame()

# %%
dp
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 429):
    response = requests.get(url, headers = headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
    dp = dp.append(temp_df, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17440\3389308878.py in ?()
#       1 for i in range(1, 429):
#       2     response = requests.get(url, headers = headers)
#       3     temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
# ----> 4     dp = dp.append(temp_df, ignore_index = True)
#
# ~\anaconda3\envs\macLearn\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
for i in range(1, 429):
    response = requests.get(url, headers = headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
    dp = dp.concat(temp_df, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17440\1339795173.py in ?()
#       1 for i in range(1, 429):
#       2     response = requests.get(url, headers = headers)
#       3     temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
# ----> 4     dp = dp.concat(temp_df, ignore_index = True)
#
# ~\anaconda3\envs\macLearn\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
for i in range(1, 429):
    response = requests.get(url, headers = headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
    dp = dp.merge(temp_df, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 response = requests.get(url, headers = headers)
#       3 temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
# ----> 4 dp = dp.merge(temp_df, ignore_index = True)
#
# TypeError: DataFrame.merge() got an unexpected keyword argument 'ignore_index'

# %%
for i in range(1, 429):
    response = requests.get(url, headers = headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
    dp = dp.merge(temp_df);
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[15], line 4
#       2 response = requests.get(url, headers = headers)
#       3 temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
# ----> 4 dp = dp.merge(temp_df)
#
# File ~\anaconda3\envs\macLearn\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
# ...

# %%
list = list()

# %%
for i in range(1, 429):
    response = requests.get(url, headers = headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
    dp = dp.merge(temp_df, on='id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17440\3790824239.py in ?()
#       1 for i in range(1, 429):
#       2     response = requests.get(url, headers = headers)
#       3     temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
# ----> 4     dp = dp.merge(temp_df, on='id')
#
# ~\anaconda3\envs\macLearn\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ...

# %%
for i in range(1, 429):
    response = requests.get(url, headers = headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
    dp = dp.join(temp_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 response = requests.get(url, headers = headers)
#       3 temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
# ----> 4 dp = dp.join(temp_df)
#
# File ~\anaconda3\envs\macLearn\Lib\site-packages\pandas\core\frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
# ...

# %%
for i in range(1, 429):
    response = requests.get(url, headers = headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
    list.append(temp_df)

# %%
dp = pd.concat(list)

# %%
dp
# Out:
#         id  popularity release_date                     title  vote_average  \
# 0      278     128.372   1994-09-23  The Shawshank Redemption         8.706
# 1      238     260.690   1972-03-14             The Godfather         8.690
# 2      240      84.401   1974-12-20     The Godfather Part II         8.575
# 3      424      96.342   1993-12-15          Schindler's List         8.565
# 4      389      68.522   1957-04-10              12 Angry Men         8.543
# ..     ...         ...          ...                       ...           ...
# 15     769     111.746   1990-09-12                GoodFellas         8.463
# 16     346      42.852   1954-04-26             Seven Samurai         8.463
# 17  667257      23.485   2021-06-17         Impossible Things         8.500
# 18   12477       0.040   1988-04-16    Grave of the Fireflies         8.458
# 19     637      41.896   1997-12-20         Life Is Beautiful         8.500
#
#     vote_count
# 0        26631
# 1        20202
# ...

# %%
dp.head(20)
# Out:
#         id  popularity release_date  \
# 0      278     128.372   1994-09-23
# 1      238     260.690   1972-03-14
# 2      240      84.401   1974-12-20
# 3      424      96.342   1993-12-15
# 4      389      68.522   1957-04-10
# 5      129     100.376   2001-07-20
# 6    19404      33.059   1995-10-20
# 7      155     158.693   2008-07-16
# 8   496243      87.142   2019-05-30
# 9      497     101.556   1999-12-10
# 10  372058      77.841   2016-08-26
# 11     680     120.692   1994-09-10
# 12     122     106.504   2003-12-01
# 13      13      96.558   1994-06-23
# 14     429      74.993   1966-12-22
# 15     769     111.746   1990-09-12
# 16     346      42.852   1954-04-26
# 17  667257      23.485   2021-06-17
# 18   12477       0.040   1988-04-16
# 19     637      41.896   1997-12-20
#
#                                             title  vote_average  vote_count
# 0                        The Shawshank Redemption         8.706       26631
# ...

# %%
dp.to_csv('movies.csv')
